# %%
import scipy.io as sio
import os
import re
import numpy as np
import pandas as pd
from PIL import Image
import pickle
import gzip
from plot_animated import plot_animated
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib.animation import FFMpegWriter
plt.rcParams['animation.ffmpeg_path'] ='C:\\ffmpeg-4.1-win64-static\\bin\\ffmpeg.exe'

# %matplotlib notebook

# helper function
def search_int_in_filename(filename):
    num_search = re.search('\d+',filename)
    return int(num_search.group(0))


folder_path = 'D:\Data\Wi_Fi Dataset\Wi-Fi dataset_CSI\\'
folder_list = os.listdir(folder_path)

df_subc = pd.DataFrame()
dict_scaled = {}
for exp_id in folder_list[1:3]: # test
    file_path = folder_path + exp_id
    file_list = os.listdir(file_path)
    file_list.sort(key=search_int_in_filename)
        
    df_sc = pd.DataFrame()
    list_scaled = []
    scalar_colname = ['timestamp_low','bfee_count','Nrx','Ntx','rssi_a','rssi_b','rssi_c','noise','agc','rate']
    for i, file in enumerate(file_list):
        data_read = sio.loadmat(os.path.join(file_path,file))
        num_search = re.search('\d+',file)
        csi_num = int(num_search.group(0))

        # scalar data
        read_sc0_8 = [data_read['csi_entry'][0][0][a][0][0] for a in range(9)]
        data_sc = pd.DataFrame(read_sc0_8).astype('int').T
        data_sc.columns=scalar_colname[0:9]
        data_sc['perm'] = pd.Series([data_read['csi_entry'][0][0][9][0]])
        data_sc['rate'] = data_read['csi_entry'][0][0][10][0][0]
        data_sc.index = [(exp_id,csi_num)]

        # csi info
        csi_raw = data_read['csi_entry'][0][0][11]
        csi_scaled = data_read['csi_entry'][0][0][12]

        # aggregate
        df_sc = df_sc.append(data_sc)
        list_scaled.append(csi_scaled)

    arr_scaled = np.array(list_scaled).reshape(-1,30,2,3)
    dict_scaled[exp_id] = arr_scaled

# %%
1
# Out:
# 1

# %%
abs_int = (np.abs(arr_scaled) / max_abs * 255).astype('uint8')
abs_img = np.zeros((abs_int.shape[0],abs_int.shape[1],3),'uint8')

# %%
abs_int.shape
# Out:
# (8831, 30, 2, 3)

# %%
abs_img.shape
# Out:
# (8831, 30, 3)

# %%
abs_int.shape
# Out:
# (8831, 30, 2, 3)

# %%
im = Image.fromarray(abs_int[:,:,0,0])
im.show()

# %%
np.max(np.abs(arr_scaled))
# Out:
# 41.12403177112758

# %%
max_abs = 50

# %%
abs_arr = np.array(np.abs(arr_scaled))
ph_arr = np.array(np.angle(arr_scaled))

# %%
abs_int = (abs_arr / max_abs * 255).astype('uint8')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-41bd39c0dd23> in <module>()
# ----> 1 abs_int = (abs_arr / max_abs * 255).astype('uint8')
#
# NameError: name 'max_abs' is not defined

# %%
plt.imshow(abs_int[:,:,0,0], cmap='hot', interpolation='nearest')
plt.savefig('aa.jpeg')

# %%
abs_int[:,:,0,0].shape
# Out:
# (8831, 30)

# %%
import seaborn as sns
ax = sns.heatmap(abs_int[:,:,0,0])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-9771daf6180b> in <module>()
#       1 import seaborn as sns
# ----> 2 ax = sns.heatmap(abs_int[:,:,0,0])
#       3 plt.show()
#
# NameError: name 'abs_int' is not defined

# %%
import seaborn as sns
ax = sns.heatmap(abs_int[:,:,1,2])
plt.yticks=cols
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-99208c6f41e2> in <module>()
#       1 import seaborn as sns
# ----> 2 ax = sns.heatmap(abs_int[:,:,1,2])
#       3 plt.yticks=cols
#       4 plt.show()
#
# NameError: name 'abs_int' is not defined

# %%
fig, ax = plt.subplots(figsize=(10,10))         # Sample figsize in inches
sns.heatmap(abs_int[:,:,1,2], annot=True, linewidths=.5, ax=ax)
plt.show()

# %%
sns_plot.savefig("output.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-310db65b0adc> in <module>()
# ----> 1 sns_plot.savefig("output.png")
#
# NameError: name 'sns_plot' is not defined

# %%
hmap = plt.subplots(figsize=(10, len(abs_arr)/50))
hmap = sns.heatmap(abs_arr[:,:,0,0],vmax=50)
fig = hmap.get_figure()
fig.savefig('hmap.png')

# %%
abs_arr.shape
# Out:
# (8831, 30, 2, 3)

# %%
arr_scaled[0].shape
# Out:
# (30, 2, 3)

# %%
im = Image.fromarray((abs_arr[:,:,0,0]/50*255).astype('uint8'))
im.save('im.jpeg')

# %%
np.mean(arr_scaled)
# Out:
# (-0.007549811769643636+0.001475702144797912j)

# %%
np.std(np.abs(arr_scaled))
# Out:
# 10.493444603125926

# %%
len(arr_scaled)
# Out:
# 8831

# %%
df_sc = pd.DataFrame(columns=['mean','std'])

# %%
    # calc mean, var
    mean_subc = np.mean(np.abs(arr_scaled))
    std_subc = np.std(np.abs(arr_scaled))
    len_subc = len(arr_scaled)

    df_subc.loc(exp_id)['mean'] = mean_subc
    df_subc.loc(exp_id)['std'] = std_subc
    df_subc.loc(exp_id)['len'] = len_subc
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-2637a7609225> in <module>()
#       4 len_subc = len(arr_scaled)
#       5
# ----> 6 df_subc.loc(exp_id)['mean'] = mean_subc
#       7 df_subc.loc(exp_id)['std'] = std_subc
#       8 df_subc.loc(exp_id)['len'] = len_subc
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __call__(self, axis)
#      96
#      97         if axis is not None:
# ---> 98             axis = self.obj._get_axis_number(axis)
#      99         new_self.axis = axis
#     100         return new_self
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(self, axis)
#     372                 pass
#     373         raise ValueError('No axis named {0} for object type {1}'
# --> 374                          .format(axis, type(self)))
#     375
#     376     def _get_axis_name(self, axis):
#
# ValueError: No axis named S001_1_1_2 for object type <class 'pandas.core.frame.DataFrame'>

# %%
df_subc.loc(exp_id)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-65370f539c17> in <module>()
# ----> 1 df_subc.loc(exp_id)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __call__(self, axis)
#      96
#      97         if axis is not None:
# ---> 98             axis = self.obj._get_axis_number(axis)
#      99         new_self.axis = axis
#     100         return new_self
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(self, axis)
#     372                 pass
#     373         raise ValueError('No axis named {0} for object type {1}'
# --> 374                          .format(axis, type(self)))
#     375
#     376     def _get_axis_name(self, axis):
#
# ValueError: No axis named S001_1_1_2 for object type <class 'pandas.core.frame.DataFrame'>

# %%
df_subc
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df_subc = pd.DataFrame(columns=['mean','std'])

# %%
df_subc
# Out:
# Empty DataFrame
# Columns: [mean, std]
# Index: []

# %%
df_subc.loc(('aa'))['mean']=1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-89-1f5524800779> in <module>()
# ----> 1 df_subc.loc(('aa'))['mean']=1
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __call__(self, axis)
#      96
#      97         if axis is not None:
# ---> 98             axis = self.obj._get_axis_number(axis)
#      99         new_self.axis = axis
#     100         return new_self
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(self, axis)
#     372                 pass
#     373         raise ValueError('No axis named {0} for object type {1}'
# --> 374                          .format(axis, type(self)))
#     375
#     376     def _get_axis_name(self, axis):
#
# ValueError: No axis named aa for object type <class 'pandas.core.frame.DataFrame'>

# %%
    ser_subc = pd.Series()
    ser_subc['mean'] = mean_subc
    ser_subc['std'] = std_subc
    ser_subc['len'] = len_subc

# %%
df_subc = df_subc.append(ser_subc,index=exp_id)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-92-8a0e976eaa17> in <module>()
# ----> 1 df_subc = df_subc.append(ser_subc,index=exp_id)
#
# TypeError: append() got an unexpected keyword argument 'index'

# %%
ser_subc.set_index=exp_id
